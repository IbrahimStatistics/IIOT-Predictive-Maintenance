# %%
import numpy as np
import h5py

# %%
matrix1 = np.random.random(size=(1000,1000))
matrix2 = np.random.random(size=(10000,100))

# %%
with h5py.File(r'C:\Users\ibrah\OneDrive\Desktop\data.h5', 'w') as hdf:
    hdf.create_dataset('Dataset1', data=matrix1)
    hdf.create_dataset('Dataset2', data=matrix2)

# %%
dataset1
# Out:
# array([[0.33718064, 0.14351812, 0.42865696, ..., 0.2985845 , 0.86091846,
#         0.25964876],
#        [0.11745633, 0.36977474, 0.05745917, ..., 0.67712227, 0.11149726,
#         0.54845449],
#        [0.53364577, 0.46810683, 0.65812149, ..., 0.62588285, 0.56832846,
#         0.4289134 ],
#        ...,
#        [0.95760019, 0.7361341 , 0.25852947, ..., 0.95193382, 0.21444215,
#         0.38667345],
#        [0.85597091, 0.80159675, 0.3078683 , ..., 0.99275845, 0.75036947,
#         0.13175727],
#        [0.10861791, 0.95028332, 0.67836117, ..., 0.74017118, 0.50332086,
#         0.4647264 ]], shape=(1000, 1000))

# %%
with h5py.File(r'C:\Users\ibrah\OneDrive\Desktop\data.h5', 'r') as hdf:
    ls = list(hdf.keys())
    print("List of datasets in this file:", ls)

    data = hdf.get("Dataset1")
    dataset1 = np.array(data)

    print("Shape of Dataset1:", dataset1.shape)
# Out:
# List of datasets in this file: ['Dataset1', 'Dataset2']
# Shape of Dataset1: (1000, 1000)

# %%
dataset1
# Out:
# array([[0.33718064, 0.14351812, 0.42865696, ..., 0.2985845 , 0.86091846,
#         0.25964876],
#        [0.11745633, 0.36977474, 0.05745917, ..., 0.67712227, 0.11149726,
#         0.54845449],
#        [0.53364577, 0.46810683, 0.65812149, ..., 0.62588285, 0.56832846,
#         0.4289134 ],
#        ...,
#        [0.95760019, 0.7361341 , 0.25852947, ..., 0.95193382, 0.21444215,
#         0.38667345],
#        [0.85597091, 0.80159675, 0.3078683 , ..., 0.99275845, 0.75036947,
#         0.13175727],
#        [0.10861791, 0.95028332, 0.67836117, ..., 0.74017118, 0.50332086,
#         0.4647264 ]], shape=(1000, 1000))

# %%
f = h5py.File(r'C:\Users\ibrah\OneDrive\Desktop\data.h5', 'r')
ls = list(f.keys())
f.close()

# %%
ls
# Out:
# ['Dataset1', 'Dataset2']

# %%
h5py.File() as hdf:
    ls = list(hdf.keys())
    print("List of datasets in this file:
# Out:
#   Cell In[33], line 3
#     print("List of datasets in this fie
#           ^
# SyntaxError: unterminated string literal (detected at line 3)
